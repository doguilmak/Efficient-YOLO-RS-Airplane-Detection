# %% [markdown]
# # **Training HRPlane Dataset with YOLOv9e: Experiment No. 60.1**
#
# <p align="center">
#     <img src="https://github.com/RSandAI/Comprehensive-YOLO-Airplane-Detection/blob/main/assets/image.png" height=450 width=1280 alt=""/>
# </p>
#
# <small>Picture Source: <a href="https://github.com/RSandAI/Comprehensive-YOLO-Airplane-Detection/">RSandAI, Comprehensive YOLO Airplane Detection</a></small>
#
# <br>

# %% [markdown]
# ## **Context**
#
# The HRPlanes dataset is a valuable resource in the domain of computer vision, particularly for tasks related to object detection, specifically focusing on aircraft within Very High Resolution (VHR) Google Earth images. This dataset comprises 3101 RGB images of major airports and aircraft boneyards, manually annotated with bounding boxes for airplanes using Plainsight (formerly HyperLabel). Quality control was conducted independently, resulting in 18,477 annotated airplanes. The dataset is split into 70% training (2170 images), 20% validation (620 images), and 10% testing (311 images) sets.
#
# <br>
#
# To facilitate accurate training and evaluation, each aircraft within the images has been meticulously labeled, resulting in a comprehensive annotation set covering a total of 18,477 aircraft instances. These annotations provide bounding box coordinates for each detected aircraft within the corresponding images.
#
# <br>
#
# Given the specifics of the HRPlanes dataset and its annotations, training object detection models like YOLOv9 would involve leveraging this rich dataset to teach the model to accurately detect and localize aircraft within VHR Google Earth images. This process would entail feeding the dataset into the YOLOv9 model architecture and iteratively training the model until satisfactory performance metrics are achieved. Access to the HRPlanes dataset provides researchers, practitioners, and developers with a valuable asset for advancing the state-of-the-art in aircraft detection algorithms, with potential applications spanning aviation security, urban planning, and defense intelligence. The dataset's availability ensures its accessibility to the wider computer vision community, fostering collaboration and innovation in this domain.
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)

# %% [markdown]
# **Hyperparameters:**
#
# | Epochs | Network size | Batch size | LR | Optimizer | Hue | Saturation | Value | Mosiac |
# |--|--|--|--|--|--|--|--|--|
# | 100 | 640x640 | 16 | 0.001 | Adam | 0.015 | 0.7 | 0.4 | 1.0 |
#
# <br>
#
# Make sure your runtime is **GPU** (_not_ CPU or TPU). And if it is an option, make sure you are using _Python 3_. You can select these settings by going to `Runtime -> Change runtime type -> Select the above mentioned settings and then press SAVE`.

# %% [markdown]
# ## **0. Initial Steps**

# %% [markdown]
# ### **0.1. Import Libraries and Connect Google Drive**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
import json
import shutil
import seaborn as sns
import os

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ### **0.2. Define Paths and Hyperparameters**

# %%
# @markdown ---

BASE_DIRECTORY = '/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_60/' # @param {type:"string"}
if os.path.exists(BASE_DIRECTORY):
    print(f"Base directory already exists: {BASE_DIRECTORY}")
else:
    os.makedirs(BASE_DIRECTORY)
    print(f"Created base directory: {BASE_DIRECTORY}")

SAVE_DIR = BASE_DIRECTORY + 'outputs'
if os.path.exists(SAVE_DIR):
    print(f"Save directory already exists: {SAVE_DIR}")
else:
    os.makedirs(SAVE_DIR)
    print(f"Created save directory: {SAVE_DIR}")

# @markdown ---

IMAGE_SIZE = 640 # @param {type:"integer"}
BATCH = 16 # @param {type:"integer"}
# SGD, Adam, AdamW
OPTIMIZER = 'Adam' # @param {type:"string"}

# @markdown ---
# Out:
# Created base directory: /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_60/
# Created save directory: /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_60/outputs

# %% [markdown]
# ### **0.3. Clone and Install**

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 668, done.
# remote: Counting objects: 100% (294/294), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 668 (delta 224), reused 201 (delta 201), pack-reused 374
# Receiving objects: 100% (668/668), 3.22 MiB | 16.67 MiB/s, done.
# Resolving deltas: 100% (269/269), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 14.6 MB/s eta 0:00:00

# %% [markdown]
# ### **0.4. Download Model Weights**

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions `yolov9-s` and `yolov9-m` are also mentioned, but the weights for these models are not yet available in the YOLOv9 [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 136940
# drwxr-xr-x 2 root root      4096 May 28 17:35 .
# drwxr-xr-x 1 root root      4096 May 28 17:35 ..
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %% [markdown]
# ## **1. Train the Model**

# %% [markdown]
# The A100 GPU is a powerful graphics processing unit (GPU) developed by NVIDIA. It is part of the NVIDIA Ampere architecture and is designed for high-performance computing tasks, including deep learning, data analytics, and scientific computing. The A100 GPU offers significant improvements in performance and efficiency compared to previous GPU models, making it ideal for demanding AI and machine learning applications.

# %%
# !nvidia-smi
# Out:
# Tue May 28 17:35:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              46W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **IMPORTANT:** Before training, check hyperparameters in `/content/yolov9/data/hyps/hyp.scratch-high.yaml`.

# %%
# !rm -rf /content/yolov9/runs/train/exp

# %%
# %cd {HOME}/yolov9

# !python train_dual.py \
--batch-size {BATCH} --epochs 25 --imgsz {IMAGE_SIZE} --device 0 \
--data /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/coco.yaml \
--weights {HOME}/weights/yolov9-e.pt \
--cfg models/detect/yolov9-e.yaml \
--hyp hyp.scratch-high.yaml \
--optimizer {OPTIMIZER}
# Out:
# /content/yolov9
# 2024-05-28 17:35:58.752374: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-28 17:35:58.804675: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-28 17:35:58.804723: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-28 17:35:58.806674: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-28 17:35:58.814953: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-28 17:36:00.002451: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train_dual: weights=/content/weights/yolov9-e.pt, cfg=models/detect/yolov9-e.yaml, data=/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/coco.yaml, hyp=hyp.scratch-high.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# hyperparameters: lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, obj=0.7, obj_pw=1.0, dfl=1.5, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 13.7MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1         0  models.common.Silence                   []
#   1                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   2                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   3                -1  1    252160  models.common.RepNCSPELAN4              [128, 256, 128, 64, 2]
#   4                -1  1    164352  models.common.ADown                     [256, 256]
#   5                -1  1   1004032  models.common.RepNCSPELAN4              [256, 512, 256, 128, 2]
#   6                -1  1    656384  models.common.ADown                     [512, 512]
#   7                -1  1   4006912  models.common.RepNCSPELAN4              [512, 1024, 512, 256, 2]
#   8                -1  1   2623488  models.common.ADown                     [1024, 1024]
#   9                -1  1   4269056  models.common.RepNCSPELAN4              [1024, 1024, 512, 256, 2]
#  10                 1  1      4160  models.common.CBLinear                  [64, [64]]
#  11                 3  1     49344  models.common.CBLinear                  [256, [64, 128]]
#  12                 5  1    229824  models.common.CBLinear                  [512, [64, 128, 256]]
#  13                 7  1    984000  models.common.CBLinear                  [1024, [64, 128, 256, 512]]
#  14                 9  1   2033600  models.common.CBLinear                  [1024, [64, 128, 256, 512, 1024]]
#  15                 0  1      1856  models.common.Conv                      [3, 64, 3, 2]
#  16[10, 11, 12, 13, 14, -1]  1         0  models.common.CBFuse                    [[0, 0, 0, 0, 0]]
#  17                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#  18[11, 12, 13, 14, -1]  1         0  models.common.CBFuse                    [[1, 1, 1, 1]]
#  19                -1  1    252160  models.common.RepNCSPELAN4              [128, 256, 128, 64, 2]
#  20                -1  1    164352  models.common.ADown                     [256, 256]
#  21  [12, 13, 14, -1]  1         0  models.common.CBFuse                    [[2, 2, 2]]
#  22                -1  1   1004032  models.common.RepNCSPELAN4              [256, 512, 256, 128, 2]
#  23                -1  1    656384  models.common.ADown                     [512, 512]
#  24      [13, 14, -1]  1         0  models.common.CBFuse                    [[3, 3]]
#  25                -1  1   4006912  models.common.RepNCSPELAN4              [512, 1024, 512, 256, 2]
#  26                -1  1   2623488  models.common.ADown                     [1024, 1024]
#  27          [14, -1]  1         0  models.common.CBFuse                    [[4]]
#  28                -1  1   4269056  models.common.RepNCSPELAN4              [1024, 1024, 512, 256, 2]
#  29                 9  1    787968  models.common.SPPELAN                   [1024, 512, 256]
#  30                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  31           [-1, 7]  1         0  models.common.Concat                    [1]
#  32                -1  1   4005888  models.common.RepNCSPELAN4              [1536, 512, 512, 256, 2]
#  33                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  34           [-1, 5]  1         0  models.common.Concat                    [1]
#  35                -1  1   1069056  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 2]
#  36                28  1    787968  models.common.SPPELAN                   [1024, 512, 256]
#  37                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  38          [-1, 25]  1         0  models.common.Concat                    [1]
#  39                -1  1   4005888  models.common.RepNCSPELAN4              [1536, 512, 512, 256, 2]
#  40                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  41          [-1, 22]  1         0  models.common.Concat                    [1]
#  42                -1  1   1069056  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 2]
#  43                -1  1    164352  models.common.ADown                     [256, 256]
#  44          [-1, 39]  1         0  models.common.Concat                    [1]
#  45                -1  1   3612672  models.common.RepNCSPELAN4              [768, 512, 512, 256, 2]
#  46                -1  1    656384  models.common.ADown                     [512, 512]
#  47          [-1, 36]  1         0  models.common.Concat                    [1]
#  48                -1  1  12860416  models.common.RepNCSPELAN4              [1024, 512, 1024, 512, 2]
#  49[35, 32, 29, 42, 45, 48]  1  10982822  models.yolo.DualDDetect                 [1, [256, 512, 512, 256, 512, 512]]
# yolov9-e summary: 1475 layers, 69407846 parameters, 69407814 gradients, 244.8 GFLOPs
#
# Transferred 2160/2172 items from /content/weights/yolov9-e.pt
# AMP: checks passed ✅
# optimizer: Adam(lr=0.001) with parameter groups 356 weight(decay=0.0), 375 weight(decay=0.0005), 373 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /gdrive/MyDrive/Datasets/HRPlanes_ds/train/labels.cache... 2170 images, 4 backgrounds, 0 corrupt: 100% 2170/2170 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /gdrive/MyDrive/Datasets/HRPlanes_ds/val/labels.cache... 620 images, 5 backgrounds, 0 corrupt: 100% 620/620 [00:00<?, ?it/s]
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/24      22.9G      2.249      4.726      1.794        270        640:   0% 0/136 [02:53<?, ?it/s]WARNING ⚠️ TensorBoard graph visualization failure Only tensors, lists, tuples of tensors, or dictionary of tensors can be output from traced functions
#        0/24      26.1G      1.331     0.9946      1.315        101        640: 100% 136/136 [08:29<00:00,  3.75s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:12<00:00,  1.65it/s]
#                    all        620       3290       0.97      0.919      0.961      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/24      26.1G      1.233     0.7007      1.273         89        640: 100% 136/136 [05:26<00:00,  2.40s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.06it/s]
#                    all        620       3290      0.965      0.935      0.964      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/24      26.1G       1.24     0.6892      1.282        101        640: 100% 136/136 [05:44<00:00,  2.53s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.13it/s]
#                    all        620       3290      0.979      0.947      0.975      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/24      27.8G      1.225     0.6659       1.27         74        640: 100% 136/136 [05:31<00:00,  2.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.01it/s]
#                    all        620       3290      0.976      0.954       0.98      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/24      27.8G      1.166     0.6319      1.252        117        640: 100% 136/136 [05:35<00:00,  2.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  1.90it/s]
#                    all        620       3290      0.976      0.959      0.984      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/24      27.8G      1.154      0.619      1.248         55        640: 100% 136/136 [05:34<00:00,  2.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.29it/s]
#                    all        620       3290      0.985      0.973      0.991      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/24      27.8G      1.115     0.5978      1.232         77        640: 100% 136/136 [05:30<00:00,  2.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.03it/s]
#                    all        620       3290      0.975       0.97       0.99      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/24      27.8G      1.111     0.5833      1.226        198        640: 100% 136/136 [05:29<00:00,  2.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.03it/s]
#                    all        620       3290      0.978      0.966      0.988      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/24        30G      1.089       0.56      1.221         71        640: 100% 136/136 [05:37<00:00,  2.48s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  2.00it/s]
#                    all        620       3290      0.982      0.968      0.989      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/24        30G      1.064     0.5486      1.208        115        640: 100% 136/136 [05:28<00:00,  2.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  1.84it/s]
#                    all        620       3290       0.98      0.967       0.99      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/24        30G      1.061     0.5321      1.201         97        640: 100% 136/136 [05:40<00:00,  2.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.08it/s]
#                    all        620       3290      0.984      0.969      0.991      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/24        30G      1.033     0.5251      1.197        142        640: 100% 136/136 [05:40<00:00,  2.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.02it/s]
#                    all        620       3290      0.985      0.979      0.992      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/24        30G      1.049     0.5277      1.201         49        640: 100% 136/136 [05:35<00:00,  2.47s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.12it/s]
#                    all        620       3290      0.982      0.978      0.991      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/24        30G      1.024     0.5173      1.189         78        640: 100% 136/136 [05:28<00:00,  2.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  1.91it/s]
#                    all        620       3290      0.985       0.98      0.992      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/24        30G     0.9809     0.4955       1.18        174        640: 100% 136/136 [05:33<00:00,  2.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.18it/s]
#                    all        620       3290      0.986      0.979      0.993      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/24        30G     0.9867     0.4926      1.189        141        640: 100% 136/136 [05:41<00:00,  2.51s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.05it/s]
#                    all        620       3290      0.981       0.98      0.992       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/24        30G     0.9748     0.4902      1.175        201        640: 100% 136/136 [05:32<00:00,  2.44s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.36it/s]
#                    all        620       3290      0.986      0.981      0.992      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/24        30G     0.9468     0.4625      1.159        152        640: 100% 136/136 [05:21<00:00,  2.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  1.99it/s]
#                    all        620       3290      0.986      0.979      0.993      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/24        30G     0.9318     0.4524      1.165         82        640: 100% 136/136 [05:32<00:00,  2.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.05it/s]
#                    all        620       3290      0.984      0.982      0.992      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/24        30G     0.9222     0.4477      1.155         95        640: 100% 136/136 [05:29<00:00,  2.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.12it/s]
#                    all        620       3290      0.982      0.986      0.993      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/24        30G     0.9283     0.4476      1.158        185        640: 100% 136/136 [05:30<00:00,  2.43s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  1.97it/s]
#                    all        620       3290      0.984      0.985      0.993      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/24        30G     0.9128     0.4391      1.153        111        640: 100% 136/136 [05:27<00:00,  2.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  1.90it/s]
#                    all        620       3290      0.985      0.986      0.993      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/24        30G     0.8903     0.4225      1.139        105        640: 100% 136/136 [05:32<00:00,  2.44s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  1.88it/s]
#                    all        620       3290      0.988      0.983      0.993      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/24        30G     0.8832     0.4206       1.14        163        640: 100% 136/136 [05:26<00:00,  2.40s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:10<00:00,  2.00it/s]
#                    all        620       3290      0.984      0.986      0.993      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/24        30G     0.8664     0.4091      1.143        182        640: 100% 136/136 [05:31<00:00,  2.44s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:09<00:00,  2.07it/s]
#                    all        620       3290      0.987      0.984      0.993      0.873
#
# 25 epochs completed in 2.506 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 139.9MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 139.9MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# yolov9-e summary: 839 layers, 68547814 parameters, 0 gradients, 240.7 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:25<00:00,  1.28s/it]
#                    all        620       3290      0.987      0.984      0.993      0.874
# Results saved to runs/train/exp

# %% [markdown]
# ## **2. Examine Training Results**

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1716917761.50f84d85b99c.3274.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
csv_file_path = f"{HOME}/yolov9/runs/train/exp/results.csv"
df = pd.read_csv(csv_file_path)
df
# Out:
#                    epoch        train/box_loss        train/cls_loss  \
# 0                      0               1.33050               0.99457
# 1                      1               1.23270               0.70070
# 2                      2               1.24000               0.68917
# 3                      3               1.22490               0.66591
# 4                      4               1.16610               0.63189
# 5                      5               1.15450               0.61904
# 6                      6               1.11480               0.59777
# 7                      7               1.11110               0.58332
# 8                      8               1.08870               0.55996
# 9                      9               1.06380               0.54862
# 10                    10               1.06140               0.53211
# 11                    11               1.03300               0.52508
# 12                    12               1.04930               0.52773
# 13                    13               1.02400               0.51734
# 14                    14               0.98093               0.49548
# 15                    15               0.98671               0.49255
# 16                    16               0.97481               0.49016
# 17                    17               0.94679               0.46246
# 18                    18               0.93176               0.45243
# 19                    19               0.92218               0.44772
# 20                    20               0.92831               0.44756
# 21                    21               0.91283               0.43913
# 22                    22               0.89032               0.42246
# 23                    23               0.88319               0.42063
# 24                    24               0.86637               0.40911
#
#           train/dfl_loss     metrics/precision        metrics/recall  \
# 0                 1.3149               0.97041               0.91945
# 1                 1.2730               0.96546               0.93452
# 2                 1.2821               0.97930               0.94711
# 3                 1.2698               0.97576               0.95436
# 4                 1.2520               0.97590               0.95866
# 5                 1.2483               0.98493               0.97335
# 6                 1.2318               0.97525               0.97027
# 7                 1.2257               0.97782               0.96596
# 8                 1.2205               0.98223               0.96778
# 9                 1.2081               0.98043               0.96687
# 10                1.2007               0.98432               0.96900
# 11                1.1970               0.98532               0.97940
# 12                1.2008               0.98229               0.97757
# 13                1.1890               0.98532               0.97951
# 14                1.1796               0.98622               0.97905
# 15                1.1889               0.98143               0.97995
# 16                1.1745               0.98580               0.98116
# 17                1.1593               0.98622               0.97923
# 18                1.1651               0.98418               0.98207
# 19                1.1553               0.98242               0.98571
# 20                1.1579               0.98448               0.98480
# 21                1.1526               0.98512               0.98582
# 22                1.1391               0.98752               0.98328
# 23                1.1401               0.98363               0.98618
# 24                1.1429               0.98749               0.98397
#
#          metrics/mAP_0.5  metrics/mAP_0.5:0.95          val/box_loss  \
# 0                0.96140               0.76416                     0
# 1                0.96377               0.74290                     0
# 2                0.97509               0.77370                     0
# 3                0.98039               0.78736                     0
# 4                0.98443               0.79663                     0
# 5                0.99112               0.80892                     0
# 6                0.99048               0.81555                     0
# 7                0.98830               0.80621                     0
# 8                0.98933               0.81200                     0
# 9                0.98978               0.82247                     0
# 10               0.99125               0.83414                     0
# 11               0.99245               0.82929                     0
# 12               0.99144               0.84372                     0
# 13               0.99181               0.84320                     0
# 14               0.99261               0.84212                     0
# 15               0.99192               0.85010                     0
# 16               0.99240               0.85293                     0
# 17               0.99251               0.86171                     0
# 18               0.99248               0.85608                     0
# 19               0.99266               0.85879                     0
# 20               0.99277               0.86690                     0
# 21               0.99283               0.86792                     0
# 22               0.99299               0.87095                     0
# 23               0.99318               0.86894                     0
# 24               0.99300               0.87347                     0
#
#             val/cls_loss          val/dfl_loss                 x/lr0  \
# 0                      0                     0              0.067243
# 1                      0                     0              0.034216
# 2                      0                     0              0.001164
# 3                      0                     0              0.000881
# 4                      0                     0              0.000881
# 5                      0                     0              0.000842
# 6                      0                     0              0.000802
# 7                      0                     0              0.000762
# 8                      0                     0              0.000723
# 9                      0                     0              0.000683
# 10                     0                     0              0.000644
# 11                     0                     0              0.000604
# 12                     0                     0              0.000564
# 13                     0                     0              0.000525
# 14                     0                     0              0.000485
# 15                     0                     0              0.000446
# 16                     0                     0              0.000406
# 17                     0                     0              0.000366
# 18                     0                     0              0.000327
# 19                     0                     0              0.000287
# 20                     0                     0              0.000248
# 21                     0                     0              0.000208
# 22                     0                     0              0.000168
# 23                     0                     0              0.000129
# 24                     0                     0              0.000089
#
#                    x/lr1                 x/lr2
# 0               0.000331              0.000331
# 1               0.000638              0.000638
# 2               0.000919              0.000919
# 3               0.000881              0.000881
# 4               0.000881              0.000881
# 5               0.000842              0.000842
# 6               0.000802              0.000802
# 7               0.000762              0.000762
# 8               0.000723              0.000723
# 9               0.000683              0.000683
# 10              0.000644              0.000644
# 11              0.000604              0.000604
# 12              0.000564              0.000564
# 13              0.000525              0.000525
# 14              0.000485              0.000485
# 15              0.000446              0.000446
# 16              0.000406              0.000406
# 17              0.000366              0.000366
# 18              0.000327              0.000327
# 19              0.000287              0.000287
# 20              0.000248              0.000248
# 21              0.000208              0.000208
# 22              0.000168              0.000168
# 23              0.000129              0.000129
# 24              0.000089              0.000089

# %% [markdown]
# ## **3. Evaluate Model**

# %%
# %cd {HOME}/yolov9

# !python val_dual.py \
# --img 640 --batch 16 \
# --data /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/coco.yaml \
# --weights {HOME}/yolov9/runs/train/exp/weights/best.pt

# %% [markdown]
# ## **4. Move Model Items into Google Drive**

# %%
BASE_DIRECTORY
# Out:
# '/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_60/'

# %% [markdown]
# Instead of uploading and downloading files, we can directly move them to the desired path.

# %%
shutil.move(f"{HOME}/yolov9/runs/", BASE_DIRECTORY)
# Out:
# '/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_60/runs'

# %%
from datetime import datetime
print(f"Changes have been made to the project on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Changes have been made to the project on 2024-05-28 20:08:05
