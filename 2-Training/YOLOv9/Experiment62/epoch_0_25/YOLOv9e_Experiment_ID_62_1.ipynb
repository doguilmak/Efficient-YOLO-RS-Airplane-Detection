# %% [markdown]
# # **Training HRPlane Dataset with YOLOv9e: Experiment No. 62.1**
#
# <p align="center">
#     <img src="https://github.com/RSandAI/Comprehensive-YOLO-Airplane-Detection/blob/main/assets/image.png" height=450 width=1280 alt=""/>
# </p>
#
# <small>Picture Source: <a href="https://github.com/RSandAI/Comprehensive-YOLO-Airplane-Detection/">RSandAI, Comprehensive YOLO Airplane Detection</a></small>
#
# <br>

# %% [markdown]
# ## **Context**
#
# The HRPlanes dataset is a valuable resource in the domain of computer vision, particularly for tasks related to object detection, specifically focusing on aircraft within Very High Resolution (VHR) Google Earth images. This dataset comprises 3101 RGB images of major airports and aircraft boneyards, manually annotated with bounding boxes for airplanes using Plainsight (formerly HyperLabel). Quality control was conducted independently, resulting in 18,477 annotated airplanes. The dataset is split into 70% training (2170 images), 20% validation (620 images), and 10% testing (311 images) sets.
#
# <br>
#
# To facilitate accurate training and evaluation, each aircraft within the images has been meticulously labeled, resulting in a comprehensive annotation set covering a total of 18,477 aircraft instances. These annotations provide bounding box coordinates for each detected aircraft within the corresponding images.
#
# <br>
#
# Given the specifics of the HRPlanes dataset and its annotations, training object detection models like YOLOv9 would involve leveraging this rich dataset to teach the model to accurately detect and localize aircraft within VHR Google Earth images. This process would entail feeding the dataset into the YOLOv9 model architecture and iteratively training the model until satisfactory performance metrics are achieved. Access to the HRPlanes dataset provides researchers, practitioners, and developers with a valuable asset for advancing the state-of-the-art in aircraft detection algorithms, with potential applications spanning aviation security, urban planning, and defense intelligence. The dataset's availability ensures its accessibility to the wider computer vision community, fostering collaboration and innovation in this domain.
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)

# %% [markdown]
# **Hyperparameters:**
#
# | Epochs | Network size | Batch size | LR | Optimizer | Hue | Saturation | Value | Mosiac |
# |--|--|--|--|--|--|--|--|--|
# | 100 | 640x640 | 16 | 0.001 | AdamW | 0.015 | 0.7 | 0.4 | 1.0 |
#
# <br>
#
# Make sure your runtime is **GPU** (_not_ CPU or TPU). And if it is an option, make sure you are using _Python 3_. You can select these settings by going to `Runtime -> Change runtime type -> Select the above mentioned settings and then press SAVE`.

# %% [markdown]
# ## **0. Initial Steps**

# %% [markdown]
# ### **0.1. Import Libraries and Connect Google Drive**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
import json
import shutil
import seaborn as sns
import os

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ### **0.2. Define Paths and Hyperparameters**

# %%
# @markdown ---

BASE_DIRECTORY = '/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_62/' # @param {type:"string"}
if os.path.exists(BASE_DIRECTORY):
    print(f"Base directory already exists: {BASE_DIRECTORY}")
else:
    os.makedirs(BASE_DIRECTORY)
    print(f"Created base directory: {BASE_DIRECTORY}")

SAVE_DIR = BASE_DIRECTORY + 'outputs'
if os.path.exists(SAVE_DIR):
    print(f"Save directory already exists: {SAVE_DIR}")
else:
    os.makedirs(SAVE_DIR)
    print(f"Created save directory: {SAVE_DIR}")

# @markdown ---

IMAGE_SIZE = 640 # @param {type:"integer"}
BATCH = 16 # @param {type:"integer"}
# SGD, Adam, AdamW
OPTIMIZER = 'AdamW' # @param {type:"string"}

# @markdown ---
# Out:
# Created base directory: /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_62/
# Created save directory: /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_62/outputs

# %% [markdown]
# ### **0.3. Clone and Install**

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 668, done.
# remote: Counting objects: 100% (294/294), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 668 (delta 224), reused 201 (delta 201), pack-reused 374
# Receiving objects: 100% (668/668), 3.22 MiB | 5.03 MiB/s, done.
# Resolving deltas: 100% (269/269), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 9.3 MB/s eta 0:00:00

# %% [markdown]
# ### **0.4. Download Model Weights**

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions `yolov9-s` and `yolov9-m` are also mentioned, but the weights for these models are not yet available in the YOLOv9 [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 136940
# drwxr-xr-x 2 root root      4096 May 30 12:00 .
# drwxr-xr-x 1 root root      4096 May 30 12:00 ..
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %% [markdown]
# ## **1. Train the Model**

# %% [markdown]
# The A100 GPU is a powerful graphics processing unit (GPU) developed by NVIDIA. It is part of the NVIDIA Ampere architecture and is designed for high-performance computing tasks, including deep learning, data analytics, and scientific computing. The A100 GPU offers significant improvements in performance and efficiency compared to previous GPU models, making it ideal for demanding AI and machine learning applications.

# %%
# !nvidia-smi
# Out:
# Thu May 30 12:00:27 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              44W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **IMPORTANT:** Before training, check hyperparameters in `/content/yolov9/data/hyps/hyp.scratch-high.yaml`.

# %%
# !rm -rf /content/yolov9/runs/train/exp

# %%
# %cd {HOME}/yolov9

# !python train_dual.py \
--batch-size {BATCH} --epochs 25 --imgsz {IMAGE_SIZE} --device 0 \
--data /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/coco.yaml \
--weights {HOME}/weights/yolov9-e.pt \
--cfg models/detect/yolov9-e.yaml \
--hyp hyp.scratch-high.yaml \
--optimizer {OPTIMIZER}
# Out:
# /content/yolov9
# 2024-05-30 12:01:00.984968: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-30 12:01:01.037308: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 12:01:01.037362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 12:01:01.039153: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-30 12:01:01.047417: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-30 12:01:02.250708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train_dual: weights=/content/weights/yolov9-e.pt, cfg=models/detect/yolov9-e.yaml, data=/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/coco.yaml, hyp=hyp.scratch-high.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=AdamW, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=0, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# hyperparameters: lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, obj=0.7, obj_pw=1.0, dfl=1.5, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 61.5MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1         0  models.common.Silence                   []
#   1                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   2                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   3                -1  1    252160  models.common.RepNCSPELAN4              [128, 256, 128, 64, 2]
#   4                -1  1    164352  models.common.ADown                     [256, 256]
#   5                -1  1   1004032  models.common.RepNCSPELAN4              [256, 512, 256, 128, 2]
#   6                -1  1    656384  models.common.ADown                     [512, 512]
#   7                -1  1   4006912  models.common.RepNCSPELAN4              [512, 1024, 512, 256, 2]
#   8                -1  1   2623488  models.common.ADown                     [1024, 1024]
#   9                -1  1   4269056  models.common.RepNCSPELAN4              [1024, 1024, 512, 256, 2]
#  10                 1  1      4160  models.common.CBLinear                  [64, [64]]
#  11                 3  1     49344  models.common.CBLinear                  [256, [64, 128]]
#  12                 5  1    229824  models.common.CBLinear                  [512, [64, 128, 256]]
#  13                 7  1    984000  models.common.CBLinear                  [1024, [64, 128, 256, 512]]
#  14                 9  1   2033600  models.common.CBLinear                  [1024, [64, 128, 256, 512, 1024]]
#  15                 0  1      1856  models.common.Conv                      [3, 64, 3, 2]
#  16[10, 11, 12, 13, 14, -1]  1         0  models.common.CBFuse                    [[0, 0, 0, 0, 0]]
#  17                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#  18[11, 12, 13, 14, -1]  1         0  models.common.CBFuse                    [[1, 1, 1, 1]]
#  19                -1  1    252160  models.common.RepNCSPELAN4              [128, 256, 128, 64, 2]
#  20                -1  1    164352  models.common.ADown                     [256, 256]
#  21  [12, 13, 14, -1]  1         0  models.common.CBFuse                    [[2, 2, 2]]
#  22                -1  1   1004032  models.common.RepNCSPELAN4              [256, 512, 256, 128, 2]
#  23                -1  1    656384  models.common.ADown                     [512, 512]
#  24      [13, 14, -1]  1         0  models.common.CBFuse                    [[3, 3]]
#  25                -1  1   4006912  models.common.RepNCSPELAN4              [512, 1024, 512, 256, 2]
#  26                -1  1   2623488  models.common.ADown                     [1024, 1024]
#  27          [14, -1]  1         0  models.common.CBFuse                    [[4]]
#  28                -1  1   4269056  models.common.RepNCSPELAN4              [1024, 1024, 512, 256, 2]
#  29                 9  1    787968  models.common.SPPELAN                   [1024, 512, 256]
#  30                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  31           [-1, 7]  1         0  models.common.Concat                    [1]
#  32                -1  1   4005888  models.common.RepNCSPELAN4              [1536, 512, 512, 256, 2]
#  33                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  34           [-1, 5]  1         0  models.common.Concat                    [1]
#  35                -1  1   1069056  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 2]
#  36                28  1    787968  models.common.SPPELAN                   [1024, 512, 256]
#  37                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  38          [-1, 25]  1         0  models.common.Concat                    [1]
#  39                -1  1   4005888  models.common.RepNCSPELAN4              [1536, 512, 512, 256, 2]
#  40                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  41          [-1, 22]  1         0  models.common.Concat                    [1]
#  42                -1  1   1069056  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 2]
#  43                -1  1    164352  models.common.ADown                     [256, 256]
#  44          [-1, 39]  1         0  models.common.Concat                    [1]
#  45                -1  1   3612672  models.common.RepNCSPELAN4              [768, 512, 512, 256, 2]
#  46                -1  1    656384  models.common.ADown                     [512, 512]
#  47          [-1, 36]  1         0  models.common.Concat                    [1]
#  48                -1  1  12860416  models.common.RepNCSPELAN4              [1024, 512, 1024, 512, 2]
#  49[35, 32, 29, 42, 45, 48]  1  10982822  models.yolo.DualDDetect                 [1, [256, 512, 512, 256, 512, 512]]
# yolov9-e summary: 1475 layers, 69407846 parameters, 69407814 gradients, 244.8 GFLOPs
#
# Transferred 2160/2172 items from /content/weights/yolov9-e.pt
# AMP: checks passed ✅
# optimizer: AdamW(lr=0.001) with parameter groups 356 weight(decay=0.0), 375 weight(decay=0.0005), 373 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /gdrive/MyDrive/Datasets/HRPlanes_ds/train/labels.cache... 2170 images, 4 backgrounds, 0 corrupt: 100% 2170/2170 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /gdrive/MyDrive/Datasets/HRPlanes_ds/val/labels.cache... 620 images, 5 backgrounds, 0 corrupt: 100% 620/620 [00:00<?, ?it/s]
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/24      22.9G      2.249      4.726      1.794        270        640:   0% 0/136 [04:13<?, ?it/s]WARNING ⚠️ TensorBoard graph visualization failure Only tensors, lists, tuples of tensors, or dictionary of tensors can be output from traced functions
#        0/24      27.5G      1.338     0.9973      1.321        101        640: 100% 136/136 [10:16<00:00,  4.53s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:11<00:00,  1.81it/s]
#                    all        620       3290      0.973      0.929      0.972      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/24      27.5G      1.247     0.7033      1.281         89        640: 100% 136/136 [06:12<00:00,  2.74s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.64it/s]
#                    all        620       3290      0.968      0.947      0.971      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/24      27.5G      1.243     0.6877      1.282        101        640: 100% 136/136 [06:22<00:00,  2.81s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.57it/s]
#                    all        620       3290      0.958      0.938      0.973      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/24      29.2G      1.197     0.6509      1.255         74        640: 100% 136/136 [06:25<00:00,  2.83s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.55it/s]
#                    all        620       3290      0.978      0.947      0.981      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/24      29.2G      1.166     0.6286      1.248        117        640: 100% 136/136 [06:22<00:00,  2.81s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.69it/s]
#                    all        620       3290       0.98      0.957      0.986      0.805
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/24      29.2G      1.142     0.6138      1.242         55        640: 100% 136/136 [06:15<00:00,  2.76s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.58it/s]
#                    all        620       3290      0.977      0.958      0.984      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/24      29.2G      1.124     0.5893      1.234         77        640: 100% 136/136 [06:11<00:00,  2.73s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.48it/s]
#                    all        620       3290      0.981      0.972      0.989      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/24      29.2G      1.104     0.5747      1.221        198        640: 100% 136/136 [06:12<00:00,  2.74s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.51it/s]
#                    all        620       3290       0.98      0.964      0.989      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/24      31.3G      1.078     0.5562      1.213         71        640: 100% 136/136 [06:42<00:00,  2.96s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.71it/s]
#                    all        620       3290      0.978       0.97      0.989      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/24      31.3G      1.055     0.5376      1.206        115        640: 100% 136/136 [06:12<00:00,  2.74s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.41it/s]
#                    all        620       3290       0.98      0.975       0.99      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/24      31.3G      1.054     0.5275      1.197         97        640: 100% 136/136 [06:18<00:00,  2.78s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.56it/s]
#                    all        620       3290      0.981      0.978      0.991      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/24      31.3G       1.03     0.5228      1.196        142        640: 100% 136/136 [05:55<00:00,  2.61s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.49it/s]
#                    all        620       3290      0.986      0.976      0.992      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/24      31.3G      1.042     0.5184      1.198         49        640: 100% 136/136 [06:09<00:00,  2.72s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.32it/s]
#                    all        620       3290      0.983      0.976      0.991      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/24      31.3G      1.011     0.5084      1.183         78        640: 100% 136/136 [06:07<00:00,  2.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.43it/s]
#                    all        620       3290      0.984       0.98      0.992       0.84
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/24      31.3G     0.9767     0.4916      1.176        174        640: 100% 136/136 [06:13<00:00,  2.75s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.41it/s]
#                    all        620       3290      0.986      0.983      0.992      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/24      31.3G     0.9806     0.4891      1.186        141        640: 100% 136/136 [06:03<00:00,  2.67s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.36it/s]
#                    all        620       3290      0.982      0.979      0.992      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/24      31.3G     0.9665     0.4848      1.169        201        640: 100% 136/136 [06:13<00:00,  2.74s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.59it/s]
#                    all        620       3290      0.982      0.985      0.993      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/24      31.3G     0.9388     0.4552      1.155        152        640: 100% 136/136 [06:10<00:00,  2.73s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.43it/s]
#                    all        620       3290      0.984      0.982      0.993      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/24      31.3G     0.9203     0.4445       1.16         82        640: 100% 136/136 [06:08<00:00,  2.71s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.63it/s]
#                    all        620       3290      0.984      0.983      0.993      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/24      31.3G     0.9188     0.4447      1.153         95        640: 100% 136/136 [06:24<00:00,  2.83s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.62it/s]
#                    all        620       3290      0.984      0.983      0.993      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/24      31.3G     0.9186     0.4403      1.154        185        640: 100% 136/136 [06:07<00:00,  2.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.40it/s]
#                    all        620       3290      0.985      0.982      0.992       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/24      31.3G     0.9045     0.4344      1.147        111        640: 100% 136/136 [06:03<00:00,  2.67s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.57it/s]
#                    all        620       3290      0.987      0.982      0.993      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/24      31.3G     0.8824     0.4189      1.134        105        640: 100% 136/136 [06:10<00:00,  2.73s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:08<00:00,  2.33it/s]
#                    all        620       3290      0.985      0.986      0.993      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/24      31.3G     0.8777     0.4178      1.137        163        640: 100% 136/136 [06:05<00:00,  2.68s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.60it/s]
#                    all        620       3290      0.986      0.981      0.993      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/24      31.3G     0.8625     0.4067       1.14        182        640: 100% 136/136 [06:16<00:00,  2.77s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:07<00:00,  2.67it/s]
#                    all        620       3290      0.981      0.989      0.993      0.874
#
# 25 epochs completed in 2.787 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 139.9MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 139.9MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# yolov9-e summary: 839 layers, 68547814 parameters, 0 gradients, 240.7 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [01:13<00:00,  3.67s/it]
#                    all        620       3290      0.981      0.989      0.993      0.874
# Results saved to runs/train/exp

# %% [markdown]
# ## **2. Examine Training Results**

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1717070463.ef6998c153be.2076.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
csv_file_path = f"{HOME}/yolov9/runs/train/exp/results.csv"
df = pd.read_csv(csv_file_path)
df
# Out:
#                    epoch        train/box_loss        train/cls_loss  \
# 0                      0               1.33800               0.99727
# 1                      1               1.24740               0.70326
# 2                      2               1.24260               0.68772
# 3                      3               1.19730               0.65087
# 4                      4               1.16640               0.62856
# 5                      5               1.14210               0.61379
# 6                      6               1.12410               0.58933
# 7                      7               1.10440               0.57470
# 8                      8               1.07760               0.55617
# 9                      9               1.05530               0.53759
# 10                    10               1.05410               0.52747
# 11                    11               1.02970               0.52283
# 12                    12               1.04170               0.51838
# 13                    13               1.01090               0.50840
# 14                    14               0.97671               0.49160
# 15                    15               0.98062               0.48910
# 16                    16               0.96653               0.48477
# 17                    17               0.93876               0.45522
# 18                    18               0.92029               0.44454
# 19                    19               0.91882               0.44473
# 20                    20               0.91862               0.44032
# 21                    21               0.90451               0.43439
# 22                    22               0.88242               0.41894
# 23                    23               0.87775               0.41783
# 24                    24               0.86250               0.40671
#
#           train/dfl_loss     metrics/precision        metrics/recall  \
# 0                 1.3211               0.97294               0.92910
# 1                 1.2806               0.96830               0.94687
# 2                 1.2817               0.95772               0.93799
# 3                 1.2552               0.97771               0.94674
# 4                 1.2479               0.98039               0.95733
# 5                 1.2419               0.97721               0.95775
# 6                 1.2342               0.98128               0.97173
# 7                 1.2215               0.98048               0.96383
# 8                 1.2132               0.97823               0.96981
# 9                 1.2061               0.97994               0.97508
# 10                1.1971               0.98056               0.97842
# 11                1.1960               0.98557               0.97559
# 12                1.1975               0.98253               0.97629
# 13                1.1832               0.98380               0.98024
# 14                1.1762               0.98627               0.98266
# 15                1.1862               0.98172               0.97948
# 16                1.1692               0.98170               0.98541
# 17                1.1555               0.98361               0.98207
# 18                1.1595               0.98388               0.98301
# 19                1.1530               0.98402               0.98328
# 20                1.1537               0.98458               0.98207
# 21                1.1473               0.98656               0.98165
# 22                1.1342               0.98528               0.98602
# 23                1.1372               0.98587               0.98085
# 24                1.1402               0.98071               0.98890
#
#          metrics/mAP_0.5  metrics/mAP_0.5:0.95          val/box_loss  \
# 0                0.97178               0.76267                     0
# 1                0.97074               0.76573                     0
# 2                0.97331               0.77575                     0
# 3                0.98138               0.79052                     0
# 4                0.98643               0.80542                     0
# 5                0.98437               0.79582                     0
# 6                0.98945               0.80427                     0
# 7                0.98886               0.81753                     0
# 8                0.98884               0.81432                     0
# 9                0.98985               0.83227                     0
# 10               0.99095               0.82486                     0
# 11               0.99225               0.83786                     0
# 12               0.99068               0.83864                     0
# 13               0.99225               0.84040                     0
# 14               0.99220               0.84615                     0
# 15               0.99205               0.84847                     0
# 16               0.99268               0.85175                     0
# 17               0.99253               0.86259                     0
# 18               0.99281               0.85639                     0
# 19               0.99285               0.86267                     0
# 20               0.99233               0.86012                     0
# 21               0.99303               0.86732                     0
# 22               0.99286               0.87246                     0
# 23               0.99294               0.87202                     0
# 24               0.99296               0.87442                     0
#
#             val/cls_loss          val/dfl_loss                 x/lr0  \
# 0                      0                     0              0.067243
# 1                      0                     0              0.034216
# 2                      0                     0              0.001164
# 3                      0                     0              0.000881
# 4                      0                     0              0.000881
# 5                      0                     0              0.000842
# 6                      0                     0              0.000802
# 7                      0                     0              0.000762
# 8                      0                     0              0.000723
# 9                      0                     0              0.000683
# 10                     0                     0              0.000644
# 11                     0                     0              0.000604
# 12                     0                     0              0.000564
# 13                     0                     0              0.000525
# 14                     0                     0              0.000485
# 15                     0                     0              0.000446
# 16                     0                     0              0.000406
# 17                     0                     0              0.000366
# 18                     0                     0              0.000327
# 19                     0                     0              0.000287
# 20                     0                     0              0.000248
# 21                     0                     0              0.000208
# 22                     0                     0              0.000168
# 23                     0                     0              0.000129
# 24                     0                     0              0.000089
#
#                    x/lr1                 x/lr2
# 0               0.000331              0.000331
# 1               0.000638              0.000638
# 2               0.000919              0.000919
# 3               0.000881              0.000881
# 4               0.000881              0.000881
# 5               0.000842              0.000842
# 6               0.000802              0.000802
# 7               0.000762              0.000762
# 8               0.000723              0.000723
# 9               0.000683              0.000683
# 10              0.000644              0.000644
# 11              0.000604              0.000604
# 12              0.000564              0.000564
# 13              0.000525              0.000525
# 14              0.000485              0.000485
# 15              0.000446              0.000446
# 16              0.000406              0.000406
# 17              0.000366              0.000366
# 18              0.000327              0.000327
# 19              0.000287              0.000287
# 20              0.000248              0.000248
# 21              0.000208              0.000208
# 22              0.000168              0.000168
# 23              0.000129              0.000129
# 24              0.000089              0.000089

# %% [markdown]
# ## **3. Evaluate Model**

# %%
# %cd {HOME}/yolov9

# !python val_dual.py \
# --img 640 --batch 16 \
# --data /gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/coco.yaml \
# --weights {HOME}/yolov9/runs/train/exp/weights/best.pt

# %% [markdown]
# ## **4. Move Model Items into Google Drive**

# %%
BASE_DIRECTORY
# Out:
# '/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_62/'

# %% [markdown]
# Instead of uploading and downloading files, we can directly move them to the desired path.

# %%
shutil.move(f"{HOME}/yolov9/runs/", BASE_DIRECTORY)
# Out:
# '/gdrive/MyDrive/Datasets/HRPlanes/YOLOV8/YOLOv9e/Experiment_No_62/runs'

# %%
from datetime import datetime
print(f"Changes have been made to the project on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Changes have been made to the project on 2024-05-30 14:50:39
